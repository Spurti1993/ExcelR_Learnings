# %% [markdown]
# <a href="https://colab.research.google.com/github/Spurti1993/ExcelR_Learnings/blob/main/DataScience%5CPythonCode%5CPandas_SelfStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_house = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df_house.tail()
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [5 rows x 9 columns]

# %%
df_house.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
df_house.size
# Out:
# 27000

# %%
df_house.ndim
# Out:
# 2

# %%
df_house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df_house.axes
# Out:
# [RangeIndex(start=0, stop=3000, step=1),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value'],
#        dtype='object')]

# %%
len(df_house.longitude)
# Out:
# 3000

# %%
df_house.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df_house[['housing_median_age','total_rooms','population']]
# Out:
#       housing_median_age  total_rooms  population
# 0                   27.0       3885.0      1537.0
# 1                   43.0       1510.0       809.0
# 2                   27.0       3589.0      1484.0
# 3                   28.0         67.0        49.0
# 4                   19.0       1241.0       850.0
# ...                  ...          ...         ...
# 2995                23.0       1450.0      1258.0
# 2996                27.0       5257.0      3496.0
# 2997                10.0        956.0       693.0
# 2998                40.0         96.0        46.0
# 2999                42.0       1765.0       753.0
#
# [3000 rows x 3 columns]

# %%
df_house.shape
# Out:
# (3000, 9)

# %%
df_house['population'].values
# Out:
# array([1537.,  809., 1484., ...,  693.,   46.,  753.])

# %%
list(df_house)
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
sector1 = list(df_house)[0:4]
sector2 = list(df_house)[4:9]
print("section one columns are ",sector1, "\n", "section two columns are ", sector2)
# Out:
# section one columns are  ['longitude', 'latitude', 'housing_median_age', 'total_rooms']
#  section two columns are  ['total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %%
df_house.empty
# Out:
# False

# %%
df_house.info
# Out:
# <bound method DataFrame.info of       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]>

# %%
df_house.count()#O/P is in data frame
# Out:
# longitude             3000
# latitude              3000
# housing_median_age    3000
# total_rooms           3000
# total_bedrooms        3000
# population            3000
# households            3000
# median_income         3000
# median_house_value    3000
# dtype: int64

# %%
df_house.count#O/p is in object
# Out:
# <bound method DataFrame.count of       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]>

# %%
df_house.describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
df_house.households.mean()
# Out:
# 489.912

# %%
df_house.latitude.median()
# Out:
# 34.27

# %%
df_house.longitude.dropna().mode()
# Out:
# 0   -118.26
# 1   -118.21
# dtype: float64

# %%
df_house.total_bedrooms.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: total_bedrooms, Length: 3000, dtype: bool

# %%
df_house.total_rooms.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: total_rooms, Length: 3000, dtype: bool

# %%
df_house.dropna().describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
min = df_house.population.min()
max = df_house.population.max()
print("Min value of population is",min,"\n","Maximum value of population is",max)
# Out:
# Min value of population is 5.0
#  Maximum value of population is 11935.0

# %%
df_house.sample(40)
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 241     -117.08     32.82  ...         7.1298            278600.0
# 1403    -122.33     37.93  ...         2.3475             90300.0
# 638     -117.83     33.83  ...         8.3818            377600.0
# 2554    -117.34     34.12  ...         3.3516            105600.0
# 2779    -119.01     35.40  ...         1.7109             44600.0
# 257     -118.64     34.22  ...         6.8643            333700.0
# 2396    -120.57     38.20  ...         2.6417            122300.0
# 265     -117.10     32.68  ...         2.0724            107600.0
# 400     -121.72     36.81  ...         3.2969            229900.0
# 726     -117.20     32.80  ...         2.3599            168400.0
# 1011    -120.32     37.29  ...         2.3382             59600.0
# 1425    -122.59     38.12  ...         6.0132            287900.0
# 2371    -117.08     32.57  ...         2.2500            103200.0
# ...

# %%
df_house.population.std()
# Out:
# 1030.5430124122422

# %%
df_house.population.var()
# Out:
# 1062018.9004316987

# %%
df_house.iloc[0:10,3:6]
# Out:
#    total_rooms  total_bedrooms  population
# 0       3885.0           661.0      1537.0
# 1       1510.0           310.0       809.0
# 2       3589.0           507.0      1484.0
# 3         67.0            15.0        49.0
# 4       1241.0           244.0       850.0
# 5       1018.0           213.0       663.0
# 6       1009.0           225.0       604.0
# 7       2310.0           471.0      1341.0
# 8       3080.0           617.0      1446.0
# 9       2402.0           632.0      2830.0

# %%
df_house.iloc[:,2:9]
# Out:
#       housing_median_age  total_rooms  ...  median_income  median_house_value
# 0                   27.0       3885.0  ...         6.6085            344700.0
# 1                   43.0       1510.0  ...         3.5990            176500.0
# 2                   27.0       3589.0  ...         5.7934            270500.0
# 3                   28.0         67.0  ...         6.1359            330000.0
# 4                   19.0       1241.0  ...         2.9375             81700.0
# ...                  ...          ...  ...            ...                 ...
# 2995                23.0       1450.0  ...         1.1790            225000.0
# 2996                27.0       5257.0  ...         3.3906            237200.0
# 2997                10.0        956.0  ...         2.2895             62000.0
# 2998                40.0         96.0  ...         3.2708            162500.0
# 2999                42.0       1765.0  ...         8.5608            500001.0
#
# [3000 rows x 7 columns]

# %%
df_house.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
df_house.groupby(['housing_median_age']).groups
# Out:
# {1.0: [842, 1115], 2.0: [495, 1050, 1271, 2117, 2429, 2452], 3.0: [182, 532, 625, 688, 1019, 1604, 1747, 1984, 2327, 2417, 2913, 2936], 4.0: [45, 93, 295, 418, 900, 1005, 1021, 1123, 1146, 1178, 1283, 1460, 1584, 1597, 1667, 1924, 1953, 2014, 2054, 2141, 2178, 2326, 2528, 2614, 2625, 2671, 2758, 2930], 5.0: [33, 190, 358, 388, 389, 403, 650, 679, 753, 825, 829, 978, 1087, 1180, 1269, 1281, 1328, 1560, 1572, 1577, 1609, 1638, 1707, 1779, 1795, 1813, 1880, 1995, 2013, 2044, 2167, 2209, 2244, 2388, 2591, 2622, 2641, 2731, 2753], 6.0: [48, 107, 249, 292, 405, 429, 430, 546, 859, 888, 1044, 1073, 1344, 1812, 1828, 1976, 2046, 2095, 2099, 2159, 2194, 2340, 2387, 2859, 2969], 7.0: [252, 530, 680, 732, 763, 774, 887, 944, 1074, 1138, 1153, 1680, 1847, 1978, 1998, 2200, 2421, 2484, 2527, 2650], 8.0: [153, 217, 496, 610, 863, 917, 927, 1208, 1221, 1222, 1320, 1386, 1417, 1435, 1944, 2069, 2274, 2420, 2482, 2613, 2669, 2677, 2728, 2869, 2899], 9.0: [269, 360, 362, 604, 793, 880, 947, 1002, 1182
# ...

# %%
df_house.groupby(['housing_median_age'])[['households','population']].mean()
# Out:
#                      households   population
# housing_median_age
# 1.0                    8.500000    20.000000
# 2.0                 1014.166667  3067.500000
# 3.0                 1020.833333  2702.583333
# 4.0                 1266.642857  3329.107143
# 5.0                  960.358974  2624.974359
# 6.0                  834.880000  2238.840000
# 7.0                  600.750000  2028.100000
# 8.0                  580.440000  1744.560000
# 9.0                  589.370370  1822.444444
# 10.0                 554.066667  1531.400000
# 11.0                 611.390244  1750.585366
# 12.0                 696.585366  2190.170732
# 13.0                 601.390244  1664.731707
# 14.0                 583.438596  1600.491228
# 15.0                 525.740260  1459.740260
# 16.0                 460.943925  1336.411215
# 17.0                 581.840000  1655.740000
# 18.0                 553.157895  1626.881579
# 19.0                 626.473684  1609.855263
# ...

# %%
df_house[df_house.total_bedrooms > 500]
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 8       -122.84     38.40  ...         3.6696            194400.0
# 9       -118.02     34.08  ...         2.3333            164200.0
# 13      -117.03     32.97  ...         4.5625            231200.0
# ...         ...       ...  ...            ...                 ...
# 2988    -122.01     36.97  ...         2.5417            260900.0
# 2991    -117.17     34.28  ...         7.1997            253800.0
# 2993    -117.91     33.60  ...         5.1048            500001.0
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
#
# [1227 rows x 9 columns]

# %%
df_house['latitude'].kurt()
# Out:
# -1.1243724704483558

# %%
df_house.median_house_value.kurtosis()
# Out:
# 0.39539899642985343

# %%
df_house.longitude.skew()
# Out:
# -0.29785763262779996

# %%
df_house.sem()
# Out:
# longitude                0.036422
# latitude                 0.038882
# housing_median_age       0.229229
# total_rooms             39.355570
# total_bedrooms           7.588776
# population              18.815055
# households               6.671675
# median_income            0.033859
# median_house_value    2065.273484
# dtype: float64

# %%
df_house.groupby(['total_bedrooms']).agg(['mean','max','min','std','var'])
# Out:
#                longitude                  ... median_house_value
#                     mean     max     min  ...                min           std           var
# total_bedrooms                            ...
# 2.0              -116.95 -116.95 -116.95  ...            55000.0           NaN           NaN
# 3.0              -114.62 -114.62 -114.62  ...           275000.0           NaN           NaN
# 4.0              -117.12 -117.12 -117.12  ...            60000.0           NaN           NaN
# 5.0              -117.11 -117.11 -117.11  ...           118800.0           NaN           NaN
# 7.0              -118.25 -118.06 -118.44  ...           175000.0  35355.339059  1.250000e+09
# ...                  ...     ...     ...  ...                ...           ...           ...
# 4522.0           -116.36 -116.36 -116.36  ...           239300.0           NaN           NaN
# 4585.0           -117.22 -117.22 -117.22  ...           280800.0           NaN           NaN
# ...

# %%
df_house.groupby(['total_bedrooms']).count()
# Out:
#                 longitude  latitude  ...  median_income  median_house_value
# total_bedrooms                       ...
# 2.0                     1         1  ...              1                   1
# 3.0                     1         1  ...              1                   1
# 4.0                     1         1  ...              1                   1
# 5.0                     1         1  ...              1                   1
# 7.0                     2         2  ...              2                   2
# ...                   ...       ...  ...            ...                 ...
# 4522.0                  1         1  ...              1                   1
# 4585.0                  1         1  ...              1                   1
# 5027.0                  1         1  ...              1                   1
# 5033.0                  1         1  ...              1                   1
# 5419.0                  1         1  ...              1                   1
#
# ...
